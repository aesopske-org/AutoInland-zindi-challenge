# %% [markdown]
# # read the data and the required libraries

# %%
import pandas as pd
import os
os.listdir()
import matplotlib.pyplot as plt
import numpy as np

# %%
train = pd.read_csv('data/Train.csv')
train.head(60)
# Out:
#             ID Policy Start Date Policy End Date        Gender  Age  \
# 0   ID_0040R73        2010-05-14      2011-05-13          Male   30
# 1   ID_0046BNK        2010-11-29      2011-11-28        Female   79
# 2   ID_005QMC3        2010-03-21      2011-03-20          Male   43
# 3   ID_0079OHW        2010-08-21      2011-08-20          Male    2
# 4   ID_00BRP63        2010-08-29      2010-12-31        Entity   20
# 5   ID_00D3EF6        2010-10-21      2011-10-20          Male   37
# 6   ID_00HHZ8Y        2010-08-02      2011-08-01        Female   40
# 7   ID_00M1X6U        2010-09-12      2011-09-11          Male   43
# 8   ID_00N7XT1        2010-07-06      2011-07-05        Female   71
# 9   ID_00QF156        2010-12-18      2011-12-17        Female   58
# 10  ID_00RDFUY        2010-12-23      2011-12-22        Female   43
# 11  ID_00TMUS4        2010-10-25      2011-10-23          Male   45
# 12  ID_00VRPZL        2010-01-03      2011-01-02          Male   51
# 13  ID_00XG988        2010-03-26      2011-03-25        Female  120
# 14  ID_019TN1T        2010-09-10      2011-09-09          Male   38
# 15  ID_01A4DSV        2010-11-19      2011-11-05          Male   81
# 16  ID_01BJS22        2010-04-26      2011-04-25        Female   69
# 17  ID_01HTP5J        2010-05-09      2011-05-08        Female   31
# 18  ID_01ITX31        2010-06-28      2011-06-27          Male   70
# 19  ID_01P8CIZ        2010-07-27      2011-06-14          Male   20
# 20  ID_01T1B6E        2010-12-13      2011-06-12        Entity   20
# 21  ID_01Z1YOR        2010-10-16      2011-10-15          Male   30
# 22  ID_01ZY7FF        2010-08-07      2011-08-06          Male   30
# 23  ID_020608O        2010-03-05      2011-03-04          Male   34
# 24  ID_022U6TV        2010-10-28      2011-10-27          Male   40
# 25  ID_02390ZY        2010-12-11      2011-12-10          Male    1
# 26  ID_02DJWEN        2010-01-23      2011-01-16          Male   41
# 27  ID_02GM2IL        2010-07-02      2011-07-01          Male   31
# 28  ID_02NAGK1        2010-03-01      2011-03-01          Male   40
# 29  ID_02O5FDM        2010-02-10      2011-02-09  Joint Gender   20
# 30  ID_02RCBEU        2010-03-16      2011-03-15          Male   47
# 31  ID_02T5M8A        2010-01-22      2011-01-21        Female   40
# 32  ID_02XA0UK        2010-10-07      2011-04-05           NaN   34
# 33  ID_034XN1U        2010-07-02      2011-07-01           NaN    2
# 34  ID_035HSJO        2010-06-21      2011-06-19        Female   36
# 35  ID_03H676V        2010-04-04      2011-04-03          Male   37
# 36  ID_03HT5Q0        2010-11-28      2011-11-27          Male   46
# 37  ID_03LHF6C        2010-08-07      2011-08-06          Male   48
# 38  ID_03O8OI6        2010-05-08      2011-05-07           NaN  120
# 39  ID_03U3I31        2010-09-06      2011-09-05          Male   39
# 40  ID_03UD6OT        2010-11-09      2011-11-08        Female   63
# 41  ID_03V06TZ        2010-03-12      2011-03-11        Female   39
# 42  ID_042RNAI        2010-02-12      2011-02-11          Male   40
# 43  ID_046FQ5I        2010-04-25      2011-04-09          Male   47
# 44  ID_04C9IRV        2010-12-25      2011-04-24        Female   36
# 45  ID_04FP4M2        2010-01-13      2011-01-12        Female   47
# 46  ID_04JEN82        2010-03-08      2011-02-09          Male   41
# 47  ID_04RDLQY        2010-07-08      2011-07-07          Male   42
# 48  ID_04RZ9TY        2010-04-15      2011-04-14          Male   38
# 49  ID_04Z1VXP        2010-09-09      2011-09-08        Female   27
# 50  ID_052YTIW        2010-06-06      2011-06-05          Male   42
# 51  ID_0559SH8        2010-05-20      2011-05-19          Male   39
# 52  ID_0577HW2        2010-04-26      2011-04-25        Female   30
# 53  ID_058FZ64        2010-04-23      2011-04-22        Female   64
# 54  ID_058YC0S        2010-11-28      2011-11-27           NaN  120
# 55  ID_05CDD8E        2010-07-31      2011-07-30          Male   36
# 56  ID_05FC0AD        2010-07-04      2011-07-03        Female   50
# 57  ID_05HTYFW        2010-08-15      2011-08-14        Female   53
# 58  ID_05R7YFI        2010-02-18      2011-02-17          Male   37
# 59  ID_05RDR1E        2010-08-21      2011-07-16          Male   33
#
#    First Transaction Date  No_Pol Car_Category Subject_Car_Colour  \
# 0              2010-05-14       1       Saloon              Black
# 1              2010-11-29       1         JEEP               Grey
# 2              2010-03-21       1       Saloon                Red
# 3              2010-08-21       1          NaN                NaN
# 4              2010-08-29       3          NaN                NaN
# 5              2010-10-21       2          NaN                NaN
# 6              2010-08-02       3          NaN                NaN
# 7              2010-09-12       1       Saloon                NaN
# 8              2010-07-06       2         JEEP              Black
# 9              2010-12-18       1          NaN                NaN
# 10             2010-12-23       1          NaN                NaN
# 11             2010-10-25       1         JEEP                NaN
# 12             2010-01-03       1       Saloon                NaN
# 13             2010-03-26       2          NaN                NaN
# 14             2010-09-10       1          NaN                NaN
# 15             2010-11-19       1          NaN        As Attached
# 16             2010-04-26       1       Saloon                NaN
# 17             2010-05-09       1       Saloon              Black
# 18             2010-06-28       1          NaN                NaN
# 19             2010-07-27       1          NaN               Blue
# 20             2010-12-13       2          NaN                NaN
# 21             2010-10-16       1          NaN                NaN
# 22             2010-08-07       1       Saloon               Grey
# 23             2010-03-05       1       Saloon               Blue
# 24             2010-10-28       2       Saloon              Black
# 25             2010-12-11       1          NaN                NaN
# 26             2010-01-23       1       Saloon             Silver
# 27             2010-07-02       1       Saloon               Grey
# 28             2010-03-01       1       Saloon                NaN
# 29             2010-02-10       1          NaN        As Attached
# 30             2010-03-16       2       Saloon                NaN
# 31             2010-01-22       1          NaN               Grey
# 32             2010-10-07       1          NaN                NaN
# 33             2010-07-02       1   Motorcycle                Red
# 34             2010-06-21       1         JEEP                NaN
# 35             2010-04-04       1       Saloon                NaN
# 36             2010-11-28       1          NaN                NaN
# 37             2010-08-07       1          NaN                NaN
# 38             2010-05-08       2         JEEP        As Attached
# 39             2010-09-06       2       Saloon                Red
# 40             2010-11-09       2       Saloon                NaN
# 41             2010-03-12       1       Saloon              Black
# 42             2010-02-12       1       Saloon                NaN
# 43             2010-04-25       1         JEEP              Black
# 44             2010-12-25       1          NaN                NaN
# 45             2010-01-13       3         JEEP                NaN
# 46             2010-03-08       2       Saloon             Silver
# 47             2010-07-08       3        Truck              Green
# 48             2010-04-15       1       Saloon              Green
# 49             2010-09-09       1          NaN                NaN
# 50             2010-06-06       1       Saloon                Red
# 51             2010-05-20       1       Saloon               Grey
# 52             2010-04-26       2       Saloon              Black
# 53             2010-04-23       1       Saloon              Black
# 54             2010-11-28       1         JEEP              Black
# 55             2010-07-31       1       Saloon                NaN
# 56             2010-07-04       1       Saloon                NaN
# 57             2010-08-15       1       Saloon                NaN
# 58             2010-02-18       1         JEEP                Ash
# 59             2010-08-21       2          NaN                NaN
#
#    Subject_Car_Make           LGA_Name            State       ProductName  \
# 0            TOYOTA                NaN              NaN       Car Classic
# 1            TOYOTA                NaN              NaN       Car Classic
# 2            TOYOTA                NaN              NaN       Car Classic
# 3               NaN                NaN              NaN           CarSafe
# 4               NaN              Lagos            Lagos             Muuve
# 5               NaN                NaN              NaN       Car Classic
# 6               NaN              Ikeja            Lagos              CVTP
# 7            TOYOTA                NaN              NaN           CarSafe
# 8            REXTON            Badagry            Benue       Car Classic
# 9               NaN            Eti-Osa          Eti-Osa       Car Classic
# 10              NaN                NaN              NaN           CarSafe
# 11            Lexus    Victoria Island            Lagos          Car Plus
# 12           TOYOTA                NaN              NaN       Car Classic
# 13           TOYOTA              Ikoyi            Lagos       Car Classic
# 14              NaN     Lagos Mainland            Lagos       Car Classic
# 15          Hyundai            EFFURUN            Delta       Car Classic
# 16           TOYOTA                NaN              NaN           CarSafe
# 17           TOYOTA                NaN              NaN       Car Classic
# 18           TOYOTA            Eti-Osa          Eti-Osa       Car Classic
# 19            Iveco           Abeokuta             Ogun              CVTP
# 20              DAF              Lagos            Lagos              CVTP
# 21              NaN                NaN              NaN       Car Classic
# 22           TOYOTA              Ikeja            Lagos       Car Classic
# 23           TOYOTA                NaN              NaN       Car Classic
# 24            Honda    Abuja Municipal  Abuja-Municipal       Car Classic
# 25              NaN                NaN              NaN           CarSafe
# 26           TOYOTA               Yaba            Benue       Car Classic
# 27           TOYOTA                NaN              NaN       Car Classic
# 28           TOYOTA                NaN              NaN           CarSafe
# 29           TOYOTA              Aguda            Benue       Car Classic
# 30           TOYOTA           Surulere            Lagos           CarSafe
# 31         Mercedes     Lagos Mainland            Lagos       Car Classic
# 32              NaN    Victoria Island            Lagos       Car Classic
# 33         Jincheng    Victoria Island            Lagos       Motor Cycle
# 34         Mercedes                NaN              NaN          Car Plus
# 35            Honda                NaN              NaN           CarSafe
# 36              NaN                NaN              NaN           CarSafe
# 37              NaN                NaN              NaN           CarSafe
# 38           TOYOTA    Victoria Island            Lagos       Car Classic
# 39           TOYOTA       Oshodi-Isolo     Oshodi-Isolo       Car Classic
# 40            ACURA    Abuja Municipal  Abuja-Municipal           CarSafe
# 41            Honda           Alimosho            Lagos       Car Classic
# 42            Honda                NaN              NaN           CarSafe
# 43             Ford  Okpe, Delta State            Delta       Car Classic
# 44              NaN                NaN              NaN       Car Classic
# 45            Lexus              Asaba            Delta       Car Classic
# 46           TOYOTA      IbadanCentral            Benue          Car Plus
# 47            Iveco           Abeokuta             Ogun              CVTP
# 48           TOYOTA                NaN              NaN       Car Classic
# 49              NaN                NaN              NaN       Car Classic
# 50           TOYOTA              Lekki            Lagos       Car Classic
# 51            Honda                NaN              NaN       Car Classic
# 52           TOYOTA        Ibeju/Lekki      Ibeju-Lekki       Car Classic
# 53           TOYOTA                NaN              NaN       Car Classic
# 54            Lexus    Victoria Island            Lagos  Customized Motor
# 55       Volkswagen                NaN              NaN           CarSafe
# 56           TOYOTA          OBANIKORO            Benue       Car Classic
# 57           TOYOTA                NaN              NaN           CarSafe
# 58            Lexus              Agege            Lagos       Car Classic
# 59              NaN             ISHERI            Benue       Car Classic
#
#     target
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
# 5        0
# 6        0
# 7        0
# 8        0
# 9        0
# 10       0
# 11       0
# 12       1
# 13       0
# 14       0
# 15       0
# 16       0
# 17       0
# 18       0
# 19       0
# 20       0
# 21       0
# 22       1
# 23       0
# 24       0
# 25       0
# 26       0
# 27       0
# 28       0
# 29       0
# 30       0
# 31       0
# 32       0
# 33       0
# 34       0
# 35       0
# 36       0
# 37       0
# 38       0
# 39       0
# 40       0
# 41       0
# 42       0
# 43       0
# 44       0
# 45       1
# 46       0
# 47       0
# 48       0
# 49       0
# 50       1
# 51       0
# 52       0
# 53       0
# 54       0
# 55       0
# 56       0
# 57       0
# 58       1
# 59       0

# %%
train.shape
# Out:
# (12079, 14)

# %%
nul = train.isnull().sum().reset_index()
nul.columns = ["columnms","Nulls"]
nul["Percentage"] = [str(round(i,3))+ "%" for i in round(nul.Nulls/train.shape[0],3)*100]
nul
# Out:
#                   columnms  Nulls Percentage
# 0                       ID      0       0.0%
# 1        Policy Start Date      0       0.0%
# 2          Policy End Date      0       0.0%
# 3                   Gender    359       3.0%
# 4                      Age      0       0.0%
# 5   First Transaction Date      0       0.0%
# 6                   No_Pol      0       0.0%
# 7             Car_Category   3738      30.9%
# 8       Subject_Car_Colour   6962      57.6%
# 9         Subject_Car_Make   2476      20.5%
# 10                LGA_Name   6476      53.6%
# 11                   State   6488      53.7%
# 12             ProductName      0       0.0%
# 13                  target      0       0.0%

# %% [markdown]
# ### Make a comment here: eg some variables have very high nulls (around 50%) eg Name and state of the respondent as well as car color and the car category

# %% [markdown]
# ## clean the date columns

# %%
print(type(train["Policy Start Date"]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
train["Policy Start Date"] = pd.DatetimeIndex(train["Policy Start Date"])
train["Policy End Date"] = pd.DatetimeIndex(train["Policy End Date"])

# %%
print(type(train["Policy Start Date"][0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
print(type(train["Policy End Date"][0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# # clean Gender

# %%
train['Gender'].value_counts()
# Out:
# Male            7617
# Female          3327
# Entity           277
# Joint Gender     223
# NOT STATED       175
# NO GENDER         66
# SEX               35
# Name: Gender, dtype: int64

# %%
train['Gender'].value_counts().plot(kind = "pie", autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Gender'>

# %%
train['Gender'].value_counts()
# Out:
# Male            7617
# Female          3327
# Entity           277
# Joint Gender     223
# NOT STATED       175
# NO GENDER         66
# SEX               35
# Name: Gender, dtype: int64

# %%
clean = []

for i in train['Gender']:
    #print(i)
    if i == "Entity":
        clean.append(np.nan)
    elif i == 'NO GENDER':
        clean.append(np.nan)
    elif i == "SEX":
        clean.append(np.nan)
    elif i == 'NOT STATED':
        clean.append(np.nan)
    else:
        clean.append(i)

train['Gender'] = clean   

#gender = []
#for i in train['Gender']:#if i == 'nan':
   # gender.append(train['Gender'].mode())
    #else:
       # gender.append(i)

# %%
train["Gender"].value_counts().plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='Gender'>

# %% [markdown]
# # clean the no of policy

# %%
#train.No_Pol.value_counts().plot(kind = "barh")# the data is numeric so a histogram is best
train.head()
train.No_Pol.hist() # comment that a majority has just one policy with decreasing number of policies as the number increases.
# Out:
# <AxesSubplot:>

# %%
train['No_Pol'].value_counts()# No cleaning required here
# Out:
# 1     9580
# 2     1696
# 3      539
# 4      206
# 5       24
# 7       17
# 10       9
# 6        8
# Name: No_Pol, dtype: int64

# %% [markdown]
# # Clean Age

# %%
train['Age'].unique()# A histogram here is also best though I also liked this
# Out:
# array([   30,    79,    43,     2,    20,    37,    40,    71,    58,
#           45,    51,   120,    38,    81,    69,    31,    70,    34,
#            1,    41,    47,    36,    46,    48,    39,    63,    42,
#           27,    64,    50,    53,    33,    23,    32,    59,    60,
#           52,    54,    44,    11,    78,    28,    29,    57,    12,
#           65,    35,    73,    56,    55,    26,    49,    18,    14,
#           62,    25,    61,    72,    82,    67,     7,    10,    68,
#           21,    76,    24,    66,     3,    93,    22,    77,    19,
#           80,     9,     6,   -76,    -2,    89,    74,    75,    84,
#           16,    90,   140,     8,     5,    13,    86,    15,   320,
#          -12,    83,    85, -6099, -5939,     4,   -22,   144,   112,
#           17,     0,    88,   -27,    87,   133,   102,   -51,   128,
#          -26,   100], dtype=int64)

# %%
train['Age'].hist() # shows some negative numbers are present in the data
# Out:
# <AxesSubplot:>

# %%
clean = []
for ages in train.Age:
    if ages <18:
        clean.append(np.nan)
    elif ages >100:
        clean.append(np.nan)
    else:
        clean.append(ages)
train['Age'] = clean

# %%
train['Age'].plot(kind = "hist")# the age now is between 18 and 100
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # clean product name (Insurance name)

# %%
train['ProductName'].value_counts().plot(kind = "barh")
# Out:
# <AxesSubplot:>

# %%
train['ProductName'].value_counts().plot(kind = "pie" , figsize = (10,11)) # No changes required here
# Out:
# <AxesSubplot:ylabel='ProductName'>

# %% [markdown]
# # Car Category cleaning

# %%
train['Car_Category'].value_counts()
# Out:
# Saloon                     6034
# JEEP                       2021
# Truck                        97
# Bus                          54
# Mini Bus                     36
# Pick Up                      30
# Motorcycle                   17
# Mini Van                     13
# Sedan                        12
# Wagon                        10
# Shape Of Vehicle Chasis       6
# Station 4 Wheel               5
# Van                           3
# Pick Up > 3 Tons              1
# CAMRY CAR HIRE                1
# Tipper Truck                  1
# Name: Car_Category, dtype: int64

# %%
cars = []
for i in train['Car_Category']:
    #print(i)
    if i in ["CAMRY CAR HIRE","Sedan" ]:
        cars.append("Saloon")
    elif i in ['Mini Van','Mini Bus','Van']:
        cars.append("Bus")
    elif i in ["Pick Up > 3 Tons"]:
        cars.append("Pick Up")
    elif i in ["Shape Of Vehicle Chasis"]:
        cars.append(np.nan)
    elif i in ["Station 4 Wheel"]:
        cars.append(np.nan)
    else:
        cars.append(i)
train['Car_Category']=cars

# %%
train['Car_Category'].value_counts().plot(kind = "pie", figsize = (10,11))
# Out:
# <AxesSubplot:ylabel='Car_Category'>

# %%
train.head(2)
# Out:
#            ID Policy Start Date Policy End Date  Gender   Age  \
# 0  ID_0040R73        2010-05-14      2011-05-13    Male  30.0
# 1  ID_0046BNK        2010-11-29      2011-11-28  Female  79.0
#
#   First Transaction Date  No_Pol Car_Category Subject_Car_Colour  \
# 0             2010-05-14       1       Saloon              Black
# 1             2010-11-29       1         JEEP               Grey
#
#   Subject_Car_Make LGA_Name State  ProductName  target
# 0           TOYOTA      NaN   NaN  Car Classic       0
# 1           TOYOTA      NaN   NaN  Car Classic       1

# %%
#Clean the colors

# %%
train["Subject_Car_Colour"].unique()
# Out:
# array(['Black', 'Grey', 'Red', nan, 'As Attached', 'Blue', 'Silver',
#        'Green', 'Ash', 'White', 'Gray & Gray', 'Wine', 'Brown',
#        'Red & Blue', 'Gold', 'Gray & Silver', 'Orange', 'Red & Black',
#        'Dark Grey', 'White & Red', 'Light Green', 'Dark Gray', 'B.Silver',
#        'Purple', 'Blue & Red', 'Red & Yellow', 'Yellow', 'Red & White',
#        'D. Red', 'Dark Red', 'Black & White', 'White & Blue', 'Cream',
#        'Dark Green', 'D. Gold', 'Champagne', 'Light Blue',
#        'Blue&White&Red', 'White & Yellow', 'Dark Blue', 'Black & Orange',
#        'Burgundy', 'Yellow & White', 'Beige Mitalic', 'Light Gray',
#        'Blue Sky'], dtype=object)

# %%
train["Subject_Car_Colour"].value_counts()
# Out:
# Black             1880
# Silver             554
# Grey               514
# As Attached        498
# Blue               361
# White              293
# Red                251
# Green              233
# Gold               173
# Ash                133
# Wine                89
# Brown               58
# Cream                8
# Yellow               8
# Dark Gray            5
# Orange               5
# White & Blue         5
# Red & White          4
# Purple               4
# Blue & Red           3
# D. Red               3
# Light Green          3
# B.Silver             2
# Black & White        2
# Gray & Silver        2
# White & Red          2
# Gray & Gray          2
# Black & Orange       2
# Dark Grey            2
# Red & Black          2
# Dark Blue            2
# Yellow & White       1
# Dark Red             1
# Beige Mitalic        1
# Blue&White&Red       1
# Red & Yellow         1
# Blue Sky             1
# Burgundy             1
# D. Gold              1
# Light Gray           1
# Champagne            1
# Red & Blue           1
# Light Blue           1
# Dark Green           1
# White & Yellow       1
# Name: Subject_Car_Colour, dtype: int64

# %%
train["Subject_Car_Colour"].value_counts().plot(kind = "bar",figsize = (15,5))
# Out:
# <AxesSubplot:>

# %%
color = []
for colour in train["Subject_Car_Colour"]:
    #print(i)
    if colour in ["D. Red" ]:
        color.append("Red")
    elif colour in ["D. Gold" ]:
        color.append("Gold")
    elif colour in ["B.Silver"]:
        color.append("Silver")
    elif colour in ["As Attached"]:
        color.append(np.nan)
    else:
        color.append(colour)
train["Subject_Car_Colour"]=color

# %% [markdown]
# # Clean the car make

# %%
train["Subject_Car_Make"].unique()
# Out:
# array(['TOYOTA', nan, 'REXTON', 'Lexus', 'Hyundai', 'Iveco', 'DAF',
#        'Honda', 'Mercedes', 'Jincheng', 'ACURA', 'Ford', 'Volkswagen',
#        'Nissan', '.', 'Pontiac', 'Range Rover', 'Kia', 'Mitsubishi',
#        'Scania', 'BMW', 'Infiniti', 'Renault', 'Volvo', 'Hummer', 'Mack',
#        'Grand Cherokee', 'Porsche', 'Peugeot', 'Land Rover', 'Chevrolet',
#        'Mazda', 'Man', 'Jeep', 'Audi', 'Suzuki', 'MINI COOPER', 'KA',
#        'As Attached', 'Innson', 'Isuzu', 'Skoda', 'Jaguar', 'Chrysler',
#        'Dodge', 'GMC', 'Land Rover.', 'Subaru', 'GAC', 'Fiat', 'Opel',
#        'Astra', 'Motorcycle', 'ZOYTE', 'Seat', 'FOTON', 'Howo', 'Lincoln',
#        'Rols Royce', 'CHANGAN', 'LIBERTY', 'ABG', 'Yamaha', 'Black',
#        'Tata', 'Ashok Leyland', 'Geely', 'Caddillac', 'Wrangler Jeep',
#        'Raston', 'MG', 'BRILLIANCE', 'Buik', 'COMMANDER', 'Bajaj'],
#       dtype=object)

# %%
train["Subject_Car_Make"].value_counts().plot(kind = "bar",figsize = (15,5))
# Out:
# <AxesSubplot:>

# %%
train["Subject_Car_Make"] = train["Subject_Car_Make"].astype(str)

# %%
car_names = []
for name in train["Subject_Car_Make"]:
    name.lower()
    if name in ["."]:
        car_names.append(np.nan)
    elif name in ["As Attached"]:
        car_names.append(np.nan)
    else:
        car_names.append(name)
train["Subject_Car_Make"] = car_names

# %%
train["Subject_Car_Make"].unique()
# Out:
# array(['TOYOTA', 'nan', 'REXTON', 'Lexus', 'Hyundai', 'Iveco', 'DAF',
#        'Honda', 'Mercedes', 'Jincheng', 'ACURA', 'Ford', 'Volkswagen',
#        'Nissan', nan, 'Pontiac', 'Range Rover', 'Kia', 'Mitsubishi',
#        'Scania', 'BMW', 'Infiniti', 'Renault', 'Volvo', 'Hummer', 'Mack',
#        'Grand Cherokee', 'Porsche', 'Peugeot', 'Land Rover', 'Chevrolet',
#        'Mazda', 'Man', 'Jeep', 'Audi', 'Suzuki', 'MINI COOPER', 'KA',
#        'Innson', 'Isuzu', 'Skoda', 'Jaguar', 'Chrysler', 'Dodge', 'GMC',
#        'Land Rover.', 'Subaru', 'GAC', 'Fiat', 'Opel', 'Astra',
#        'Motorcycle', 'ZOYTE', 'Seat', 'FOTON', 'Howo', 'Lincoln',
#        'Rols Royce', 'CHANGAN', 'LIBERTY', 'ABG', 'Yamaha', 'Black',
#        'Tata', 'Ashok Leyland', 'Geely', 'Caddillac', 'Wrangler Jeep',
#        'Raston', 'MG', 'BRILLIANCE', 'Buik', 'COMMANDER', 'Bajaj'],
#       dtype=object)

# %%
train["LGA_Name"].value_counts().plot(kind = "pie",figsize = (20,20))
# Out:
# <AxesSubplot:ylabel='LGA_Name'>

# %%
train["LGA_Name"].value_counts()
# Out:
# Victoria Island    1162
# Ikeja               401
# Surulere            288
# Abuja Municipal     232
# Lagos Mainland      222
#                    ...
# Ilesha                1
# Garki                 1
# EMENE                 1
# OWODE                 1
# Oyo West              1
# Name: LGA_Name, Length: 258, dtype: int64

# %% [markdown]
# # clean the States

# %%
train["State"].value_counts().plot(kind = "bar",figsize = (20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Check the targets

# %%
train.target.value_counts() # this is a very imbalanced dataset
# Out:
# 0    10624
# 1     1455
# Name: target, dtype: int64

# %% [markdown]
# # research questions

# %% [markdown]
# * whats the corelation between insurance and all the variables
# * does color corelate with insurance (particularly black, grey and white)
# * is there any relationship between state/region and insurance claims
#
# -  we should investigate this further in the bivariate analysis.

# %%
# the clean dataset
train.to_csv("clean_data/Cleaned_train_all.csv")

# %%
# impute the nulls
train.isnull().sum()
# Out:
# ID                           0
# Policy Start Date            0
# Policy End Date              0
# Gender                     912
# Age                        931
# First Transaction Date       0
# No_Pol                       0
# Car_Category              3749
# Subject_Car_Colour        7460
# Subject_Car_Make            55
# LGA_Name                  6476
# State                     6488
# ProductName                  0
# target                       0
# dtype: int64
